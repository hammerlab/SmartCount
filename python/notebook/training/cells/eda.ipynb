# %% [markdown]
# ## Cell Model Dataset EDA

# %%
import os
import os.path as osp
import glob
import celldom
import pandas as pd
import matplotlib.pyplot as plt
from skimage import io
plt.gray()

# %%
# Contains pre-annotated images from post-G3 chip
dir1 = osp.join(celldom.get_dataset_dir(), 'dataset03', 'ApartmentTraining')
dir1
# Out:
# '/lab/data/celldom/dataset/dataset03/ApartmentTraining'

# %%
# Contains pre-annotated images from G3 chip
dir2 = osp.join(celldom.get_dataset_dir(), 'dataset02')
dir2
# Out:
# '/lab/data/celldom/dataset/dataset02'

# %%
# !ls $dir1 | head
# Out:
# BF_ST_006_APT_020-1nMQuiz-02-03-201805311723-z_0-0267-0338-09.jpeg
# BF_ST_006_APT_020-1nMQuiz-02-03-201805311723-zm3-0267-0338-10.jpeg
# BF_ST_006_APT_020-1nMQuiz-02-03-201805311723-zm6-0268-0337-12.jpeg
# BF_ST_006_APT_020-1nMQuiz-02-03-201805311723-zm9-0267-0337-10.jpeg
# BF_ST_006_APT_020-1nMQuiz-02-03-201805311723-zp3-0267-0337-10.jpeg
# BF_ST_006_APT_020-1nMQuiz-02-03-201805311723-zp6-0267-0338-10.jpeg
# BF_ST_006_APT_020-1nMQuiz-02-03-201805311723-zp9-0267-0337-06.jpeg
# BF_ST_006_APT_020-1nMQuiz-02-03-201805312215-z_0-0259-0347-01.jpeg
# BF_ST_006_APT_020-1nMQuiz-02-03-201805312215-zm3-0259-0346-01.jpeg
# BF_ST_006_APT_020-1nMQuiz-02-03-201805312215-zm6-0260-0346-00.jpeg
# ls: write error: Broken pipe

# %%
# !ls $dir2 | head
# Out:
# BF_ST_000_APT_000Day0.jpg
# BF_ST_000_APT_000Day1.jpg
# BF_ST_000_APT_000Day2.jpg
# BF_ST_000_APT_000Day3.jpg
# BF_ST_000_APT_001Day0.jpg
# BF_ST_000_APT_001Day1.jpg
# BF_ST_000_APT_001Day2.jpg
# BF_ST_000_APT_001Day3.jpg
# BF_ST_000_APT_002Day0.jpg
# BF_ST_000_APT_002Day1.jpg
# ls: write error: Broken pipe

# %%
img = io.imread(osp.join(dir2, 'BF_ST_000_APT_001Day0.jpg'))
img.shape, img.dtype
# Out:
# ((300, 324, 3), dtype('uint8'))

# %%
plt.imshow(img)

# %%
img = io.imread(osp.join(dir1, 'BF_ST_006_APT_020-1nMQuiz-02-03-201805311723-zp6-0267-0338-10.jpeg'))
img.shape, img.dtype
# Out:
# ((310, 235), dtype('uint8'))

# %%
plt.imshow(img)
